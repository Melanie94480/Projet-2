# %%
import pandas as pd
import requests
from io import BytesIO
import gzip

# URL du fichier IMDB (par exemple title.basics.tsv.gz)
url = "https://datasets.imdbws.com/title.akas.tsv.gz"

# Télécharger le fichier
response = requests.get(url)
response.raise_for_status()  # Vérifie que le téléchargement s'est bien passé

# Décompresser et charger dans un DataFrame
with gzip.open(BytesIO(response.content), 'rt') as f:
    df = pd.read_csv(f, sep='\t')

# %%
df_akas=df.copy()

# %%
df_akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Carmencita     \N       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3                 Carmencita     US       \N
# 3         tt0000001         4  Carmencita - spanyol tánc     HU       \N
# 4         tt0000001         5                 Καρμενσίτα     GR       \N
# ...             ...       ...                        ...    ...      ...
# 50439851  tt9916852         7                エピソード #3.20     JP       ja
# 50439852  tt9916852         8             Episodio #3.20     ES       es
# 50439853  tt9916856         1                   The Wind     \N       \N
# 50439854  tt9916856         2                   The Wind     DE       \N
# 50439855  tt9916880         1  Horrid Henry Knows It All     \N       \N
#
#                 types     attributes  isOriginalTitle
# 0            original             \N                1
# 1                  \N  literal title                0
# 2         imdbDisplay             \N                0
# 3         imdbDisplay             \N                0
# 4         imdbDisplay             \N                0
# ...               ...            ...              ...
# 50439851           \N             \N                0
# 50439852           \N             \N                0
# 50439853     original             \N                1
# 50439854  imdbDisplay             \N                0
# 50439855     original             \N                1
#
# [50439856 rows x 8 columns]

# %%
df_akas.drop(df_akas[df_akas['region'] == '\\N'].index, inplace=True)

# %%
df_akas[df_akas['region']=='US']
# Out:
#             titleId  ordering                                      title  \
# 2         tt0000001         3                                 Carmencita
# 13        tt0000002         6                     The Clown and His Dogs
# 19        tt0000003         3                               Poor Pierrot
# 39        tt0000005         3                           Blacksmith Scene
# 41        tt0000005         5                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 50439260  tt9916560         2  March of Dimes Presents: Once Upon a Dime
# 50439356  tt9916620         2                          The Copeland Case
# 50439476  tt9916702         2              Loving London: The Playground
# 50439539  tt9916756         2                   Pretty Pretty Black Girl
# 50439558  tt9916764         2                                         38
#
#          region language        types             attributes  isOriginalTitle
# 2            US       \N  imdbDisplay                     \N                0
# 13           US       \N           \N  literal English title                0
# 19           US       \N  imdbDisplay                     \N                0
# 39           US       \N  imdbDisplay                     \N                0
# 41           US       \N  alternative                     \N                0
# ...         ...      ...          ...                    ...              ...
# 50439260     US       \N  imdbDisplay                     \N                0
# 50439356     US       \N  imdbDisplay                     \N                0
# 50439476     US       \N           \N                     \N                0
# 50439539     US       \N  imdbDisplay                     \N                0
# 50439558     US       \N  imdbDisplay                     \N                0
#
# [1574619 rows x 8 columns]

# %%
df_filtered = df[(df['language'] == 'fr') | (df['language'] == 'en')]

# %%
df_filtered
# Out:
#             titleId  ordering                                title region  \
# 38        tt0000005         2                     Blacksmith Scene     CA
# 89        tt0000010         2  La sortie de l'usine Lumière à Lyon     CA
# 120       tt0000012        21  The Arrival of a Train at La Ciotat    XWW
# 130       tt0000012         4               The Arrival of a Train    XEU
# 132       tt0000012         6               The Arrival of a Train    XWW
# ...             ...       ...                                  ...    ...
# 50439816  tt9916844         4                        Épisode #3.15     FR
# 50439824  tt9916846         4                        Épisode #3.18     FR
# 50439832  tt9916848         4                        Épisode #3.17     FR
# 50439840  tt9916850         4                        Épisode #3.19     FR
# 50439848  tt9916852         4                        Épisode #3.20     FR
#
#          language        types attributes  isOriginalTitle
# 38             en  imdbDisplay         \N                0
# 89             en  imdbDisplay         \N                0
# 120            en  alternative         \N                0
# 130            en  imdbDisplay         \N                0
# 132            en  imdbDisplay         \N                0
# ...           ...          ...        ...              ...
# 50439816       fr           \N         \N                0
# 50439824       fr           \N         \N                0
# 50439832       fr           \N         \N                0
# 50439840       fr           \N         \N                0
# 50439848       fr           \N         \N                0
#
# [5319063 rows x 8 columns]

# %%
df_filtered[df_filtered['region']=='US']
# Out:
#             titleId  ordering  \
# 3496      tt0000969        11
# 17853     tt0005809         7
# 26235     tt0008305        11
# 32536     tt0009968        45
# 76414     tt0018455        50
# ...             ...       ...
# 50395969  tt9896876        20
# 50423177  tt9909874         8
# 50423220  tt9909916         9
# 50423244  tt9909954         8
# 50423372  tt9910024         8
#
#                                                       title region language  \
# 3496                                         Les Misérables     US       en
# 17853                                          The Governor     US       en
# 26235                                        Les Misérables     US       en
# 32536                                       Broken Blossoms     US       en
# 76414                                               Sunrise     US       en
# ...                                                     ...    ...      ...
# 50395969                            India Sweets and Spices     US       en
# 50423177  Halloween: Resurrection - On the Set with Jami...     US       en
# 50423220  Halloween: Resurrection - Tour of Set with Pro...     US       en
# 50423244      Halloween: Resurrection - Head Cam Featurette     US       en
# 50423372  Halloween 4 and 5 Cast Panel at the H25 Conven...     US       en
#
#          types attributes  isOriginalTitle
# 3496        \N         \N                0
# 17853       \N         \N                0
# 26235       \N         \N                0
# 32536       \N         \N                0
# 76414       \N         \N                0
# ...        ...        ...              ...
# 50395969    \N         \N                0
# 50423177    \N         \N                0
# 50423220    \N         \N                0
# 50423244    \N         \N                0
# 50423372    \N         \N                0
#
# [3896 rows x 8 columns]
