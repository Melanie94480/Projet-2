# %%
import pandas as pd
import numpy as np
link="https://datasets.imdbws.com/title.ratings.tsv.gz"
df_rating=pd.read_csv(link, sep = '\t')

# %%
print(df_rating.head())
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2104
# 1  tt0000002            5.6       283
# 2  tt0000003            6.5      2124
# 3  tt0000004            5.4       182
# 4  tt0000005            6.2      2852

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503996 entries, 0 to 1503995
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1503996 non-null  object
#  1   averageRating  1503996 non-null  float64
#  2   numVotes       1503996 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 34.4+ MB

# %%
#verifier si il y a des cases vides
pd.set_option('display.float_format', '{:,.2f}'.format)
df_rating.describe().T
# Out:
#                      count     mean       std  min   25%   50%    75%  \
# averageRating 1,503,996.00     6.95      1.39 1.00  6.20  7.10   7.90
# numVotes      1,503,996.00 1,027.76 17,763.71 5.00 11.00 26.00 100.00
#
#                        max
# averageRating        10.00
# numVotes      2,967,477.00

# %%
#verifier si il y a des colonnes avec des valeurs vides
print(df_rating.columns[df_rating.isna().any()])
# Out:
# Index([], dtype='object')

# %%
df_rating2=df_rating.copy()

# %%
print(df_rating2.averageRating	.value_counts())
print(df_rating2.numVotes.value_counts())
# Out:
# averageRating
# 7.20    56807
# 7.40    53968
# 7.60    53815
# 7.80    52450
# 7.00    51565
#         ...
# 1.20      486
# 1.60      483
# 1.40      428
# 1.30      371
# 1.10      360
# Name: count, Length: 91, dtype: int64
# numVotes
# 7         63402
# 8         61681
# 9         58129
# 6         57955
# 10        52033
#           ...
# 176346        1
# 14792         1
# 10992         1
# 11365         1
# 18977         1
# Name: count, Length: 22812, dtype: int64

# %%
df_rating2['averageRating'].sum()
# Out:
# 10458681.899999997

# %%
df_rating2
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001           5.70      2104
# 1        tt0000002           5.60       283
# 2        tt0000003           6.50      2124
# 3        tt0000004           5.40       182
# 4        tt0000005           6.20      2852
# ...            ...            ...       ...
# 1503991  tt9916730           7.00        12
# 1503992  tt9916766           7.10        24
# 1503993  tt9916778           7.20        37
# 1503994  tt9916840           6.90        11
# 1503995  tt9916880           7.90         9
#
# [1503996 rows x 3 columns]

# %%
#verifier les doublons sur id
print(df_rating2.tconst.duplicated().sum())
# Out:
# 0

# %%
print(df_rating2['numVotes'].dtype)
print(df_rating2['averageRating'].dtype)
# Out:
# int64
# float64

# %%
condition= df_rating2['averageRating']=='\\N'

print(df_rating2[condition])
# Out:
# Empty DataFrame
# Columns: [tconst, averageRating, numVotes]
# Index: []

# %%
df_rating2
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001           5.70      2104
# 1        tt0000002           5.60       283
# 2        tt0000003           6.50      2124
# 3        tt0000004           5.40       182
# 4        tt0000005           6.20      2852
# ...            ...            ...       ...
# 1503991  tt9916730           7.00        12
# 1503992  tt9916766           7.10        24
# 1503993  tt9916778           7.20        37
# 1503994  tt9916840           6.90        11
# 1503995  tt9916880           7.90         9
#
# [1503996 rows x 3 columns]

# %%
#On va filtrer
#la moyenne des nombres de votes tournant autour de 1000, nous allons filtré sur les films ayant plus de 1000 votes
#meme raisonnement pour la moyenne de notes
condition2=(df_rating2['averageRating'] >= df_rating2['averageRating'].mean()) & (df_rating2['numVotes']>= df_rating2['numVotes'].mean())
df_rating2=df_rating2[condition2]

# %%
df_rating2.describe()
# Out:
#        averageRating     numVotes
# count      50,688.00    50,688.00
# mean            7.91    17,877.32
# std             0.64    87,793.49
# min             7.00     1,028.00
# 25%             7.40     1,531.00
# 50%             7.80     2,645.00
# 75%             8.30     5,668.25
# max            10.00 2,967,477.00

# %%
df_title_rating=df_rating2
df_title_rating
# Out:
#             tconst  averageRating  numVotes
# 11       tt0000012           7.40     13199
# 13       tt0000014           7.10      6007
# 199      tt0000211           7.40      4936
# 274      tt0000359           7.10      3311
# 300      tt0000417           8.10     57326
# ...            ...            ...       ...
# 1503750  tt9913050           7.90      4305
# 1503795  tt9913352           9.00      4575
# 1503871  tt9913754           7.30      5425
# 1503941  tt9915898           9.40      3916
# 1503942  tt9915906           8.60      1854
#
# [50688 rows x 3 columns]
